# %% [markdown]
# # 1. Data Science Tools and Ecosystem #

# %% [markdown]
# ![2-title.png](attachment:4214a65c-a714-4e47-b371-0a29a363130e.png)

# %% [markdown]
# # 2. In this notebook, Data Science Tools and Ecosystem are summarized. #

# %% [markdown]
# ![3-intro.png](attachment:f219388e-4e72-4bc9-ba01-c4c985ad6221.png)

# %% [markdown]
# # 3. Some of the popular languages that Data Scientists use are: #
# 1. R programming language
# 2. Python
# 3. C++
# 4. Java

# %% [markdown]
# ![4-dslanguages.png](attachment:0b876344-e1e5-4bd5-ac8f-01a077e14b10.png)

# %% [markdown]
# # 4. Some of the commonly used libraries used by Data Scientists include: #
# 1. caret
# 2. scikit-learn
# 3. pandas
# 4. numPy
# 5. tensorFlow

# %% [markdown]
# ![5-dslibraries.png](attachment:7fc65603-cbb8-41f5-bfab-b87ddfed64a9.png)

# %% [markdown]
# # 5. #
# | Data Science Tools|
# |---|
# |Jupyter|
# |Apache Spark|
# |Weka|

# %% [markdown]
# ![6-dstools.png](attachment:4efeb2d8-1d34-4803-ad3f-8ebce8b0f329.png)

# %% [markdown]
# ### 6. Below are a few examples of evaluating arithmetic expressions in Python ###
#  +, -, /, *, %

# %% [markdown]
# ![7-introarithmetic.png](attachment:055a2a1c-23b6-439d-a1c2-3c1cec81ee39.png)

# %%
# This a simple arithmetic expression to mutiply then add integers

(3*4) + 5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:93d0772b-5cf1-4a23-8316-b14db80d0bf2.png)

# %%
# This will convert 200 minutes to hours by diving by 60

f'{200 / 60} hours'
# Out:
# '3.3333333333333335 hours'

# %% [markdown]
# ![9-hourstominutes.png](attachment:7d2c3fd2-f1e5-4636-9077-05ae729e4a4f.png)

# %% [markdown]
# # Objectives from the notebook are: #
# - Tools for data science
# - Libraries for data science
# - Arithmetic expressions in python
# - Using markdowns in jupyter

# %% [markdown]
# ![10-objectives.png](attachment:86750f62-9b06-4320-a26e-f55a929b290c.png)

# %% [markdown]
# ## Author: ##
#  Olarinde Joseph Korede

# %% [markdown]
# ![11-authordetails.png](attachment:9c460204-5c1a-4daa-b8ab-65bbb808efe0.png)
